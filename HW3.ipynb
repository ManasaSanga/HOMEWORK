# %%
import datetime
import pandas_datareader as pdr
import pandas as pd

api_key='79bd28b2297ebff81ae8dbdb6e6391d995121302' # <your OWN API token aka key goes her


tickers = ['AAPL', 'MSFT', 'IBM', 'GOOG']


start="2020-1-1"
end="2021-7-1"

df = pdr.tiingo.TiingoDailyReader(tickers, start=start, end=end, api_key=api_key)


all_data = df.read()
all_data
# Out:
#                                     close     high        low       open  \
# symbol date
# AAPL   2020-01-02 00:00:00+00:00   300.35   300.60   295.1900   296.2400
#        2020-01-03 00:00:00+00:00   297.43   300.58   296.5000   297.1500
#        2020-01-06 00:00:00+00:00   299.80   299.96   292.7500   293.7900
#        2020-01-07 00:00:00+00:00   298.39   300.90   297.4800   299.8400
#        2020-01-08 00:00:00+00:00   303.19   304.44   297.1600   297.1600
# ...                                   ...      ...        ...        ...
# GOOG   2021-06-25 00:00:00+00:00  2539.90  2550.10  2528.8800  2539.1400
#        2021-06-28 00:00:00+00:00  2536.39  2546.74  2519.4756  2540.0000
#        2021-06-29 00:00:00+00:00  2520.37  2540.00  2508.7400  2535.4500
#        2021-06-30 00:00:00+00:00  2506.32  2516.00  2495.1500  2513.0713
#        2021-07-01 00:00:00+00:00  2527.37  2529.25  2496.9950  2496.9950
#
#                                     volume    adjClose     adjHigh  \
# ...

# %%
# Import matplotlib
import matplotlib.pyplot as plt 

# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['adjClose']].reset_index().pivot('date', 'symbol', 'adjClose')

# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = daily_close_px.pct_change()

# Plot the distributions
daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))

# Show the resulting plot
plt.show()

# %%
#Homework 3 starts here

api_key = '79bd28b2297ebff81ae8dbdb6e6391d995121302'

#tickers used are [PepsiCo, Costco, Novo, Oracle]
tickers2 = ['PEP', 'COST', 'NVO', 'ORCL']


start="2020-1-1"
end="2021-7-1"

df = pdr.tiingo.TiingoDailyReader(tickers2, start=start, end=end, api_key=api_key)


all_data2 = df.read()
all_data2
# Out:
#                                    close     high      low    open    volume  \
# symbol date
# PEP    2020-01-02 00:00:00+00:00  135.82  137.230  135.140  136.87   3596407
#        2020-01-03 00:00:00+00:00  135.63  136.790  135.130  135.46   4000070
#        2020-01-06 00:00:00+00:00  136.15  136.320  135.200  135.30   4085432
#        2020-01-07 00:00:00+00:00  134.01  136.070  133.950  136.00   5722453
#        2020-01-08 00:00:00+00:00  134.70  135.360  134.070  134.46   3681357
# ...                                  ...      ...      ...     ...       ...
# ORCL   2021-06-25 00:00:00+00:00   78.46   78.610   77.563   78.03  12845044
#        2021-06-28 00:00:00+00:00   78.50   78.965   78.330   78.49   5605358
#        2021-06-29 00:00:00+00:00   78.10   78.590   77.820   78.54   5392865
#        2021-06-30 00:00:00+00:00   77.84   78.210   77.580   77.59   7899840
#        2021-07-01 00:00:00+00:00   79.54   79.620   77.910   77.98  13108048
#
# ...

# %%
#to save the above data into csv we use

all_data2.to_csv('stock_price_for_multiple_tickers.csv')

# %%
#to read the data from csv we use

all_data_csv = pd.read_csv('stock_price_for_multiple_tickers.csv')

#to display the data from csv we use
all_data_csv
# Out:
#      symbol                       date   close     high      low    open  \
# 0       PEP  2020-01-02 00:00:00+00:00  135.82  137.230  135.140  136.87
# 1       PEP  2020-01-03 00:00:00+00:00  135.63  136.790  135.130  135.46
# 2       PEP  2020-01-06 00:00:00+00:00  136.15  136.320  135.200  135.30
# 3       PEP  2020-01-07 00:00:00+00:00  134.01  136.070  133.950  136.00
# 4       PEP  2020-01-08 00:00:00+00:00  134.70  135.360  134.070  134.46
# ...     ...                        ...     ...      ...      ...     ...
# 1507   ORCL  2021-06-25 00:00:00+00:00   78.46   78.610   77.563   78.03
# 1508   ORCL  2021-06-28 00:00:00+00:00   78.50   78.965   78.330   78.49
# 1509   ORCL  2021-06-29 00:00:00+00:00   78.10   78.590   77.820   78.54
# 1510   ORCL  2021-06-30 00:00:00+00:00   77.84   78.210   77.580   77.59
# 1511   ORCL  2021-07-01 00:00:00+00:00   79.54   79.620   77.910   77.98
#
#         volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# ...

# %%
#to isolate the 'ADJ Close, Date and Symbol' values and transform the DataFrame we use

daily_close_px_new = all_data_csv[['adjClose', 'date', 'symbol']].reset_index().pivot('date','symbol', 'adjClose')

#to calculate the daily percentage change for 'daily_close_px' we use

daily_pct_change_new = daily_close_px_new.pct_change()

#to plot the distributions we use
daily_pct_change_new.hist(bins=60, sharex=True, figsize=(12,10))

#to show the result in a plot we use
plt.show()

# %% [markdown]
# Observation- The above Histogram shows us various percentage changes in different time periods and gives us closing price values for companies between first of january 2020 to first of july 2021. This changes are used for many reasons in some cases they are used to check the margi of the company and sales made in each year. The stocks i used were for Pepsi, Costco, NOVO, and oracle and they are a change in their distrubitions as we can see in above graph the plots vary from single peak to down. Pepsi has the high varing concentration as it begins from negtive number and raises high but however in the closing it has come down but still it is on a positive scale i.e from -0.05 to 0. Oracle was also in a negative scale from -0.10 to 0 and costco, novo are on a positive scale from beginning they had no negative plots when compared with other companies.
