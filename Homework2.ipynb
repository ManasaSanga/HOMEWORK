# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
# symbol 'GOOG' is for the period of 01-01-2020 to 01-01-2021.
# start_date=datetime.dt(2020-01-01), end_date=datetime.dt(2021-01-02)
to_start='2020-01-01' #to show the start date
to_end='2021-01-01' #to show the end date
google_stock = pdr.get_data_yahoo('GOOG',to_start,to_end)
google_stock
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  68.406998  67.077499  67.077499  68.368500  28132000  68.368500
# 2020-01-03  68.625000  67.277199  67.392998  68.032997  23728000  68.032997
# 2020-01-06  69.824997  67.500000  67.500000  69.710503  34646000  69.710503
# 2020-01-07  70.149498  69.518997  69.897003  69.667000  30054000  69.667000
# 2020-01-08  70.579002  69.542000  69.603996  70.216003  30560000  70.216003
# ...               ...        ...        ...        ...       ...        ...
# 2020-12-24  87.300003  86.455498  86.750000  86.942497   6936000  86.942497
# 2020-12-28  89.536400  87.316750  87.581749  88.804497  27860000  88.804497
# 2020-12-29  89.622002  87.804497  89.389503  87.935997  25988000  87.935997
# 2020-12-30  88.254753  86.279999  88.100502  86.975998  26122000  86.975998
# 2020-12-31  87.946503  86.771004  86.771004  87.594002  20238000  87.594002
#
# [253 rows x 6 columns]

# %%
#to save the above data into csv file we use
google_stock.to_csv('data_google_stock.csv')

# %%
# for reading the file we saved into csv we use
google = pd.read_csv('data_google_stock.csv', header=0, index_col='Date')

google
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-01-02  68.406998  67.077499  67.077499  68.368500  28132000  68.368500
# 2020-01-03  68.625000  67.277199  67.392998  68.032997  23728000  68.032997
# 2020-01-06  69.824997  67.500000  67.500000  69.710503  34646000  69.710503
# 2020-01-07  70.149498  69.518997  69.897003  69.667000  30054000  69.667000
# 2020-01-08  70.579002  69.542000  69.603996  70.216003  30560000  70.216003
# ...               ...        ...        ...        ...       ...        ...
# 2020-12-24  87.300003  86.455498  86.750000  86.942497   6936000  86.942497
# 2020-12-28  89.536400  87.316750  87.581749  88.804497  27860000  88.804497
# 2020-12-29  89.622002  87.804497  89.389503  87.935997  25988000  87.935997
# 2020-12-30  88.254753  86.279999  88.100502  86.975998  26122000  86.975998
# 2020-12-31  87.946503  86.771004  86.771004  87.594002  20238000  87.594002
#
# [253 rows x 6 columns]

# %%
#to plot the closing finance for data finance stock we use
google['Close'].plot(grid=True)
#to plot y-axis we use
plt.ylabel('closing price')
#to name the plot we use
plt.title('Data for google stock 2020', y = 1)
#to show the plot we use
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#(symbol 'MSFT'), for time period between 01-01-2020 to 01-01-2021.
#start_date=datetime.dt(2020-01-01), end_date=datetime.dt(2021-01-02)
to_start='2020-01-01' #to show the start date
to_end='2021-01-01' #to show the end date
msft_stock = pdr.get_data_yahoo('MSFT', to_start, to_end)
msft_stock
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  160.729996  158.330002  158.779999  160.619995  22622100.0
# 2020-01-03  159.949997  158.059998  158.320007  158.619995  21116200.0
# 2020-01-06  159.100006  156.509995  157.080002  159.029999  20813700.0
# 2020-01-07  159.669998  157.320007  159.320007  157.580002  21634100.0
# 2020-01-08  160.800003  157.949997  158.929993  160.089996  27746500.0
# ...                ...         ...         ...         ...         ...
# 2020-12-24  223.610001  221.199997  221.419998  222.750000  10550600.0
# 2020-12-28  226.029999  223.020004  224.449997  224.960007  17933500.0
# 2020-12-29  227.179993  223.580002  226.309998  224.149994  17403200.0
# 2020-12-30  225.630005  221.470001  225.229996  221.679993  20272300.0
# 2020-12-31  223.000000  219.679993  221.699997  222.419998  20942100.0
#
#              Adj Close
# Date
# 2020-01-02  156.924408
# 2020-01-03  154.970413
# 2020-01-06  155.370956
# ...

# %%
#to save the above data into csv file we use
msft_stock.to_csv('msft_finance_stock.csv')

# %%
# for reading the file we saved into csv we use
microsoft = pd.read_csv('msft_finance_stock.csv', header=0, index_col='Date')

microsoft
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  160.729996  158.330002  158.779999  160.619995  22622100.0
# 2020-01-03  159.949997  158.059998  158.320007  158.619995  21116200.0
# 2020-01-06  159.100006  156.509995  157.080002  159.029999  20813700.0
# 2020-01-07  159.669998  157.320007  159.320007  157.580002  21634100.0
# 2020-01-08  160.800003  157.949997  158.929993  160.089996  27746500.0
# ...                ...         ...         ...         ...         ...
# 2020-12-24  223.610001  221.199997  221.419998  222.750000  10550600.0
# 2020-12-28  226.029999  223.020004  224.449997  224.960007  17933500.0
# 2020-12-29  227.179993  223.580002  226.309998  224.149994  17403200.0
# 2020-12-30  225.630005  221.470001  225.229996  221.679993  20272300.0
# 2020-12-31  223.000000  219.679993  221.699997  222.419998  20942100.0
#
#              Adj Close
# Date
# 2020-01-02  156.924408
# 2020-01-03  154.970413
# 2020-01-06  155.370956
# ...

# %%
#to plot the closing finance for data finance stock we use
microsoft['Close'].plot(grid=True)
#to plot y-axis we use
plt.ylabel('closing price')
#to name the plot we use
plt.title('Data for microsoft finance stock 2020', y = 1)
#to show the plot we use
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
